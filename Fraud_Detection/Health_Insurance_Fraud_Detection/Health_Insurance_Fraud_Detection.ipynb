# %%
import os
files = []
for file in os.listdir("Dataset_Health_Insurance"):
    file_path = os.path.join("Dataset_Health_Insurance", file)
    files.append(file_path)

# %%
len(files)
# Out:
# 9

# %%
files[0]
# Out:
# 'Dataset_Health_Insurance\\Claim_Diagnosis_Code_Dictionary.csv'

# %%
import pandas as pd
claims_code = pd.read_csv(files[0])
claims_code.head()
# Out:
#   DIAGNOSIS CODE                       LONG DESCRIPTION  \
# 0           0010         Cholera due to vibrio cholerae
# 1           0011  Cholera due to vibrio cholerae el tor
# 2           0019                   Cholera, unspecified
# 3           0020                          Typhoid fever
# 4           0021                    Paratyphoid fever A
#
#           SHORT DESCRIPTION  Unnamed: 3
# 0  Cholera d/t vib cholerae         NaN
# 1    Cholera d/t vib el tor         NaN
# 2               Cholera NOS         NaN
# 3             Typhoid fever         NaN
# 4       Paratyphoid fever a         NaN

# %%
df_test = pd.read_csv(files[1])
df_test.head()
# Out:
#    Provider
# 0  PRV51002
# 1  PRV51006
# 2  PRV51009
# 3  PRV51010
# 4  PRV51018

# %%
df_test_beneficiary_data = pd.read_csv(files[2])
df_test_beneficiary_data.head()
# Out:
#       BeneID         DOB         DOD  Gender  Race RenalDiseaseIndicator  \
# 0  BENE11001  1943-01-01         NaN       1     1                     0
# 1  BENE11007  1940-09-01  2009-12-01       1     2                     0
# 2  BENE11010  1936-07-01         NaN       2     1                     0
# 3  BENE11011  1914-03-01         NaN       2     2                     0
# 4  BENE11014  1938-04-01         NaN       2     1                     Y
#
#    State  County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ...  \
# 0     39     230                   12                   12  ...
# 1     45     610                   12                   12  ...
# 2     41      30                   12                   12  ...
# 3      1     360                   12                   12  ...
# 4     45     780                   12                   12  ...
#
#    ChronicCond_Depression  ChronicCond_Diabetes  ChronicCond_IschemicHeart  \
# ...

# %%
df_test_inpatient_data = pd.read_csv(files[3])
df_test_inpatient_data
# Out:
#           BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0      BENE11014  CLM67387   2009-09-09  2009-09-16  PRV57070
# 1      BENE11017  CLM31237   2008-12-25  2009-01-08  PRV54750
# 2      BENE11026  CLM78930   2009-12-09  2009-12-13  PRV53758
# 3      BENE11031  CLM56810   2009-06-23  2009-07-06  PRV55825
# 4      BENE11085  CLM34625   2009-01-20  2009-01-31  PRV52338
# ...          ...       ...          ...         ...       ...
# 9546  BENE159139  CLM61015   2009-07-24  2009-07-26  PRV55021
# 9547  BENE159143  CLM42885   2009-03-16  2009-03-29  PRV55017
# 9548  BENE159155  CLM67124   2009-09-07  2009-10-12  PRV53758
# 9549  BENE159181  CLM72016   2009-10-14  2009-10-17  PRV57195
# 9550  BENE159196  CLM47313   2009-04-17  2009-04-18  PRV51854
#
#       InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                       9000          PHY317786          PHY427017
# 1                      14000          PHY314656          PHY426644
# ...

# %%
df_test_outpatient_data = pd.read_csv(files[4])
df_test_outpatient_data.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM392397   2009-06-02  2009-06-02  PRV55962
# 1  BENE11001  CLM430760   2009-06-23  2009-06-23  PRV56112
# 2  BENE11007  CLM233081   2009-03-07  2009-03-07  PRV56979
# 3  BENE11007  CLM496381   2009-07-29  2009-07-29  PRV56573
# 4  BENE11007  CLM521391   2009-08-12  2009-08-12  PRV56573
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY347633                NaN
# 1                      30          PHY381777                NaN
# 2                     200          PHY425311                NaN
# 3                      10          PHY393253          PHY347995
# 4                      10          PHY417685                NaN
#
#   OtherPhysician ClmDiagnosisCode_1  ... ClmDiagnosisCode_9  \
# 0      PHY347633              V5832  ...                NaN
# 1      PHY381777               9594  ...                NaN
# ...

# %%
df_train = pd.read_csv(files[5])
df_train.head()
# Out:
#    Provider PotentialFraud
# 0  PRV51001             No
# 1  PRV51003            Yes
# 2  PRV51004             No
# 3  PRV51005            Yes
# 4  PRV51007             No

# %%
df_train_beneficiary_data = pd.read_csv(files[6])
df_train_beneficiary_data.head()
# Out:
#       BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  State  \
# 0  BENE11001  1943-01-01  NaN       1     1                     0     39
# 1  BENE11002  1936-09-01  NaN       2     1                     0     39
# 2  BENE11003  1936-08-01  NaN       1     1                     0     52
# 3  BENE11004  1922-07-01  NaN       1     1                     0     39
# 4  BENE11005  1935-09-01  NaN       1     1                     0     24
#
#    County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ...  \
# 0     230                   12                   12  ...
# 1     280                   12                   12  ...
# 2     590                   12                   12  ...
# 3     270                   12                   12  ...
# 4     680                   12                   12  ...
#
#    ChronicCond_Depression  ChronicCond_Diabetes  ChronicCond_IschemicHeart  \
# 0                       1                     1                          1
# ...

# %%
df_train_inpatient_data = pd.read_csv(files[7])
df_train_inpatient_data.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt  ... ClmDiagnosisCode_7  ClmDiagnosisCode_8  \
# 0            NaN  2009-04-12  ...               2724               19889
# 1            NaN  2009-08-31  ...                NaN                 NaN
# ...

# %%
df_train_outpatient_data = pd.read_csv(files[8])
df_train_outpatient_data.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11003  CLM189947   2009-02-12  2009-02-12  PRV57610
# 2  BENE11003  CLM438021   2009-06-27  2009-06-27  PRV57595
# 3  BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 4  BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      80          PHY362868                NaN
# 2                      10          PHY328821                NaN
# 3                      40          PHY334319                NaN
# 4                     200          PHY403831                NaN
#
#   OtherPhysician ClmDiagnosisCode_1  ... ClmDiagnosisCode_9  \
# 0            NaN              78943  ...                NaN
# 1            NaN               6115  ...                NaN
# ...

# %% [markdown]
# ### Data Wrangling

# %%
df_train["PotentialFraud"].value_counts()
# Out:
# PotentialFraud
# No     4904
# Yes     506
# Name: count, dtype: int64

# %%
Provider_type = df_train['Provider']
Fraud_Class = df_train['PotentialFraud']

# %%
df_train_inpatient_data
# Out:
#            BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0       BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1       BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2       BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3       BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4       BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
# ...           ...       ...          ...         ...       ...
# 40469  BENE159167  CLM69886   2009-09-28  2009-10-02  PRV53671
# 40470  BENE159175  CLM74504   2009-11-03  2009-11-06  PRV54981
# 40471  BENE159177  CLM76485   2009-11-18  2009-11-22  PRV56588
# 40472  BENE159177  CLM79949   2009-12-17  2009-12-18  PRV56575
# 40473  BENE159188  CLM69948   2009-09-28  2009-10-06  PRV54765
#
#        InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                       26000          PHY390922                NaN
# 1                        5000          PHY318495          PHY318495
# ...

# %%
df_train_inpatient_data = df_train_inpatient_data.merge(df_train[['Provider', 'PotentialFraud']], on='Provider', how='left')

# %%
df_train_inpatient_data
# Out:
#            BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0       BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1       BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2       BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3       BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4       BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
# ...           ...       ...          ...         ...       ...
# 40469  BENE159167  CLM69886   2009-09-28  2009-10-02  PRV53671
# 40470  BENE159175  CLM74504   2009-11-03  2009-11-06  PRV54981
# 40471  BENE159177  CLM76485   2009-11-18  2009-11-22  PRV56588
# 40472  BENE159177  CLM79949   2009-12-17  2009-12-18  PRV56575
# 40473  BENE159188  CLM69948   2009-09-28  2009-10-06  PRV54765
#
#        InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                       26000          PHY390922                NaN
# 1                        5000          PHY318495          PHY318495
# ...

# %%
df_train_inpatient_data['PotentialFraud'] = df_train_inpatient_data['PotentialFraud'].map({'Yes':1,"No":0})

# %%
df_train_inpatient_data
# Out:
#            BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0       BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1       BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2       BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3       BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4       BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
# ...           ...       ...          ...         ...       ...
# 40469  BENE159167  CLM69886   2009-09-28  2009-10-02  PRV53671
# 40470  BENE159175  CLM74504   2009-11-03  2009-11-06  PRV54981
# 40471  BENE159177  CLM76485   2009-11-18  2009-11-22  PRV56588
# 40472  BENE159177  CLM79949   2009-12-17  2009-12-18  PRV56575
# 40473  BENE159188  CLM69948   2009-09-28  2009-10-06  PRV54765
#
#        InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                       26000          PHY390922                NaN
# 1                        5000          PHY318495          PHY318495
# ...

# %%
len(df_train_beneficiary_data.columns)
# Out:
# 25

# %%
df_train_inpatient_data['BeneID'] = df_train_inpatient_data['BeneID'].astype(str)
df_train_beneficiary_data['BeneID'] = df_train_beneficiary_data['BeneID'].astype(str)

# %%
df_train_inpatient_data = df_train_inpatient_data.merge(df_train_beneficiary_data, on='BeneID', how='left')

# %%
df_train_inpatient_data
# Out:
#            BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0       BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1       BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2       BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3       BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4       BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
# ...           ...       ...          ...         ...       ...
# 40469  BENE159167  CLM69886   2009-09-28  2009-10-02  PRV53671
# 40470  BENE159175  CLM74504   2009-11-03  2009-11-06  PRV54981
# 40471  BENE159177  CLM76485   2009-11-18  2009-11-22  PRV56588
# 40472  BENE159177  CLM79949   2009-12-17  2009-12-18  PRV56575
# 40473  BENE159188  CLM69948   2009-09-28  2009-10-06  PRV54765
#
#        InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                       26000          PHY390922                NaN
# 1                        5000          PHY318495          PHY318495
# ...

# %%
df_train_inpatient_data.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6', 'PotentialFraud', 'DOB', 'DOD', 'Gender', 'Race',
#        'RenalDiseaseIndicator', 'State', 'County', 'NoOfMonths_PartACov',
#        'NoOfMonths_PartBCov', 'ChronicCond_Alzheimer',
#        'ChronicCond_Heartfailure', 'ChronicCond_KidneyDisease',
# ...

# %%
# Move 'PotentialFraud' column to the end
column_order = [col for col in df_train_inpatient_data.columns if col != 'PotentialFraud'] + ['PotentialFraud']
df_train_inpatient_data = df_train_inpatient_data[column_order]

# %%
df_train_inpatient_data.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6', 'DOB', 'DOD', 'Gender', 'Race',
#        'RenalDiseaseIndicator', 'State', 'County', 'NoOfMonths_PartACov',
#        'NoOfMonths_PartBCov', 'ChronicCond_Alzheimer',
#        'ChronicCond_Heartfailure', 'ChronicCond_KidneyDisease',
#        'ChronicCond_Cancer', 'ChronicCond_ObstrPulmonary',
# ...

# %%
df_train_inpatient_data
# Out:
#            BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0       BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1       BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2       BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3       BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4       BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
# ...           ...       ...          ...         ...       ...
# 40469  BENE159167  CLM69886   2009-09-28  2009-10-02  PRV53671
# 40470  BENE159175  CLM74504   2009-11-03  2009-11-06  PRV54981
# 40471  BENE159177  CLM76485   2009-11-18  2009-11-22  PRV56588
# 40472  BENE159177  CLM79949   2009-12-17  2009-12-18  PRV56575
# 40473  BENE159188  CLM69948   2009-09-28  2009-10-06  PRV54765
#
#        InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                       26000          PHY390922                NaN
# 1                        5000          PHY318495          PHY318495
# ...

# %%
df_ipd = df_train_inpatient_data
df_ipd.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6', 'DOB', 'DOD', 'Gender', 'Race',
#        'RenalDiseaseIndicator', 'State', 'County', 'NoOfMonths_PartACov',
#        'NoOfMonths_PartBCov', 'ChronicCond_Alzheimer',
#        'ChronicCond_Heartfailure', 'ChronicCond_KidneyDisease',
#        'ChronicCond_Cancer', 'ChronicCond_ObstrPulmonary',
# ...

# %%
df_ipd['RenalDiseaseIndicator'] = df_ipd['RenalDiseaseIndicator'].map({"Y":1, "0":0})
df_ipd['RenalDiseaseIndicator']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 40469    0
# 40470    0
# 40471    1
# 40472    1
# 40473    1
# Name: RenalDiseaseIndicator, Length: 40474, dtype: int64

# %%
df_ipd['ChronicCond_Alzheimer'] = df_ipd['ChronicCond_Alzheimer'].replace({1:0, 2:1})
df_ipd['ChronicCond_Alzheimer']
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 40469    1
# 40470    1
# 40471    0
# 40472    0
# 40473    1
# Name: ChronicCond_Alzheimer, Length: 40474, dtype: int64

# %%
df_ipd['ChronicCond_Heartfailure'] = df_ipd['ChronicCond_Heartfailure'].replace({1:0, 2:1})
df_ipd['ChronicCond_KidneyDisease'] = df_ipd['ChronicCond_KidneyDisease'].replace({1:0, 2:1})
df_ipd['ChronicCond_Cancer'] = df_ipd['ChronicCond_Cancer'].replace({1:0, 2:1})
df_ipd['ChronicCond_ObstrPulmonary'] = df_ipd['ChronicCond_ObstrPulmonary'].replace({1:0, 2:1})
df_ipd['ChronicCond_Depression'] = df_ipd['ChronicCond_Depression'].replace({1:0, 2:1})
df_ipd['ChronicCond_Diabetes'] = df_ipd['ChronicCond_Diabetes'].replace({1:0, 2:1})
df_ipd['ChronicCond_IschemicHeart'] = df_ipd['ChronicCond_IschemicHeart'].replace({1:0, 2:1})
df_ipd['ChronicCond_Osteoporasis'] = df_ipd['ChronicCond_Osteoporasis'].replace({1:0, 2:1})
df_ipd['ChronicCond_rheumatoidarthritis'] = df_ipd['ChronicCond_rheumatoidarthritis'].replace({1:0, 2:1})
df_ipd['ChronicCond_stroke'] = df_ipd['ChronicCond_stroke'].replace({1:0, 2:1})

# %%
df_ipd.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6', 'DOB', 'DOD', 'Gender', 'Race',
#        'RenalDiseaseIndicator', 'State', 'County', 'NoOfMonths_PartACov',
#        'NoOfMonths_PartBCov', 'ChronicCond_Alzheimer',
#        'ChronicCond_Heartfailure', 'ChronicCond_KidneyDisease',
#        'ChronicCond_Cancer', 'ChronicCond_ObstrPulmonary',
# ...

# %%
df_ipd['OPAnnualReimbursementAmt'].describe()
# Out:
# count     40474.000000
# mean       1897.183130
# std        3949.299161
# min         -70.000000
# 25%         190.000000
# 50%         730.000000
# 75%        2020.000000
# max      102960.000000
# Name: OPAnnualReimbursementAmt, dtype: float64

# %%
# scale the data appropriately
from sklearn.preprocessing import RobustScaler

df_ipd['InscClaimAmtReimbursed'] = RobustScaler().fit_transform(df_ipd['InscClaimAmtReimbursed'].to_numpy().reshape(-1,1))
df_ipd['IPAnnualReimbursementAmt'] = RobustScaler().fit_transform(df_ipd['IPAnnualReimbursementAmt'].to_numpy().reshape(-1,1))
df_ipd['IPAnnualDeductibleAmt'] = RobustScaler().fit_transform(df_ipd['IPAnnualDeductibleAmt'].to_numpy().reshape(-1,1))
df_ipd['IPAnnualDeductibleAmt'] = RobustScaler().fit_transform(df_ipd['IPAnnualDeductibleAmt'].to_numpy().reshape(-1,1))

# %%
df_ipd.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6', 'DOB', 'DOD', 'Gender', 'Race',
#        'RenalDiseaseIndicator', 'State', 'County', 'NoOfMonths_PartACov',
#        'NoOfMonths_PartBCov', 'ChronicCond_Alzheimer',
#        'ChronicCond_Heartfailure', 'ChronicCond_KidneyDisease',
#        'ChronicCond_Cancer', 'ChronicCond_ObstrPulmonary',
# ...

# %%
pd.set_option('display.max_columns', None)
df_ipd.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   2.375          PHY390922                NaN
# 1                  -0.250          PHY318495          PHY318495
# 2                  -0.250          PHY372395                NaN
# 3                  -0.250          PHY369659          PHY392961
# 4                   0.375          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN  2009-08-31                  6186             1068.0
# ...

# %%
df_ipd_ml = df_ipd.drop(columns=['BeneID', 'ClaimID','Provider','ClaimStartDt','ClaimEndDt','AdmissionDt','DischargeDt','AttendingPhysician','OperatingPhysician','OtherPhysician','DOB','DOD','State','County','OPAnnualReimbursementAmt','OPAnnualDeductibleAmt','ClmAdmitDiagnosisCode', 'DiagnosisGroupCode'])
df_ipd_ml
# Out:
#        InscClaimAmtReimbursed  DeductibleAmtPaid ClmDiagnosisCode_1  \
# 0                       2.375             1068.0               1970
# 1                      -0.250             1068.0               6186
# 2                      -0.250             1068.0              29623
# 3                      -0.250             1068.0              43491
# 4                       0.375             1068.0                042
# ...                       ...                ...                ...
# 40469                   0.000             1068.0               2851
# 40470                  -0.375             1068.0              42823
# 40471                  -0.500             1068.0               4280
# 40472                  -0.250             1068.0               7802
# 40473                   1.000             1068.0               1540
#
#       ClmDiagnosisCode_2 ClmDiagnosisCode_3 ClmDiagnosisCode_4  \
# 0                   4019               5853               7843
# ...

# %% [markdown]
# ### Billing for a Service Not Provided

# %% [markdown]
# The idea is for claims labeled True while procedure labeled false should indicate a fraudulent case. So The specific type of Code wouldnt matter in this case.

# %%
df_ipd_ml.columns[4:20]
# Out:
# Index(['ClmDiagnosisCode_3', 'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5',
#        'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8',
#        'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10', 'ClmProcedureCode_1',
#        'ClmProcedureCode_2', 'ClmProcedureCode_3', 'ClmProcedureCode_4',
#        'ClmProcedureCode_5', 'ClmProcedureCode_6', 'Gender', 'Race'],
#       dtype='object')

# %%
# Selecting the columns of interest
columns_of_interest = df_ipd_ml.columns[4:20]

# Applying the transformation: 'NaN' -> 0 and all other values -> 1
df_ipd_ml[columns_of_interest] = df_ipd_ml[columns_of_interest].applymap(lambda x: 0 if pd.isna(x) else 1)
# Out:
# C:\Users\agarc\AppData\Local\Temp\ipykernel_19648\252954518.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_ipd_ml[columns_of_interest] = df_ipd_ml[columns_of_interest].applymap(lambda x: 0 if pd.isna(x) else 1)

# %%
df_ipd_ml.head()
# Out:
#    InscClaimAmtReimbursed  DeductibleAmtPaid ClmDiagnosisCode_1  \
# 0                   2.375             1068.0               1970
# 1                  -0.250             1068.0               6186
# 2                  -0.250             1068.0              29623
# 3                  -0.250             1068.0              43491
# 4                   0.375             1068.0                042
#
#   ClmDiagnosisCode_2  ClmDiagnosisCode_3  ClmDiagnosisCode_4  \
# 0               4019                   1                   1
# 1               2948                   1                   0
# 2              30390                   1                   1
# 3               2762                   1                   1
# 4               3051                   1                   1
#
#    ClmDiagnosisCode_5  ClmDiagnosisCode_6  ClmDiagnosisCode_7  \
# 0                   1                   1                   1
# 1                   0                   0                   0
# ...

# %%
# Loop through each column to convert strings to floats
for column in df_ipd_ml.columns:
    df_ipd_ml[column] = pd.to_numeric(df_ipd_ml[column], errors='coerce')

# Drop rows with NaN values (resulting from the conversion failure)
df_ipd_ml.dropna(inplace=True)

# Verify the result
print(df_ipd_ml.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33753 entries, 0 to 40473
# Data columns (total 37 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   InscClaimAmtReimbursed           33753 non-null  float64
#  1   DeductibleAmtPaid                33753 non-null  float64
#  2   ClmDiagnosisCode_1               33753 non-null  float64
#  3   ClmDiagnosisCode_2               33753 non-null  float64
#  4   ClmDiagnosisCode_3               33753 non-null  int64
#  5   ClmDiagnosisCode_4               33753 non-null  int64
#  6   ClmDiagnosisCode_5               33753 non-null  int64
#  7   ClmDiagnosisCode_6               33753 non-null  int64
#  8   ClmDiagnosisCode_7               33753 non-null  int64
#  9   ClmDiagnosisCode_8               33753 non-null  int64
#  10  ClmDiagnosisCode_9               33753 non-null  int64
#  11  ClmDiagnosisCode_10              33753 non-null  int64
# ...

# %%
df2 = df_ipd_ml.sample(frac=1)

# %%
df2.head()
# Out:
#        InscClaimAmtReimbursed  DeductibleAmtPaid  ClmDiagnosisCode_1  \
# 31666                  -0.375             1068.0             81381.0
# 39801                   0.000             1068.0             49121.0
# 14487                   0.375             1068.0             43491.0
# 23868                  -0.250             1068.0             49322.0
# 33476                  -0.875             1068.0             72252.0
#
#        ClmDiagnosisCode_2  ClmDiagnosisCode_3  ClmDiagnosisCode_4  \
# 31666             53081.0                   1                   1
# 39801              4280.0                   1                   1
# 14487             34290.0                   1                   1
# 23868             27801.0                   1                   1
# 33476              4019.0                   1                   1
#
#        ClmDiagnosisCode_5  ClmDiagnosisCode_6  ClmDiagnosisCode_7  \
# 31666                   1                   1                   1
# ...

# %%
not_frauds = df2.query('PotentialFraud == 0')
frauds = df2.query('PotentialFraud == 1')

# %%
print("Instances before Balance: ",df2['PotentialFraud'].value_counts()) # check the number of instances of 'Frauds' and 'Non-Frauds' to check class imbalance.
balanced_df2 = pd.concat([not_frauds, frauds.sample(len(not_frauds))]) # Creates a balanced dataset by same number of Non-Fradulent transactions as there are fraudulent ones.
print("Instances after balance: ",balanced_df2['PotentialFraud'].value_counts()) # verify the class distribution to ensure data balance.
# There is 14219 Fraud cases and 14219 non-Fraud cases. Total of 28,438 rows.
balanced_df2 = balanced_df2.sample(frac=1) # shuffle the balanced dataset to ensure randomness after concatenation.
balanced_df2_np = balanced_df2.to_numpy()
# Out:
# Instances before Balance:  PotentialFraud
# 1    19534
# 0    14219
# Name: count, dtype: int64
# Instances after balance:  PotentialFraud
# 0    14219
# 1    14219
# Name: count, dtype: int64

# %% [markdown]
# The data is presenting a larger count of fraudulent cases than non-fraudulent.

# %%
# Split the dataset into training, testing, and validation sets
# Total of 984 Transations - Training Set: 70% (19907), Test Set: 15% (4266), Validation Set: 15% (4265)
x_train_b, y_train_b = balanced_df2_np[:19907, :-1], balanced_df2_np[:19907, -1].astype(int) # The first 700 samples used for training
x_test_b, y_test_b = balanced_df2_np[19907:24173, :-1], balanced_df2_np[19907:24173, -1].astype(int) # The next 142 samples are used for testing
x_val_b, y_val_b = balanced_df2_np[24173:, :-1], balanced_df2_np[24173:, -1].astype(int) # The remaining samples are used for validation

# %%
# Print the shapes of the training, testing, and validation sets to verify correct splitting
print("Shapes: ",x_train_b.shape, y_train_b.shape, x_test_b.shape, y_test_b.shape, x_val_b.shape, y_val_b.shape)
# Out:
# Shapes:  (19907, 36) (19907,) (4266, 36) (4266,) (4265, 36) (4265,)

# %%
# Count and display the number of instances in each class for training, testing, and validation sets
print("Count and Number of Instances: ", pd.Series(y_train_b).value_counts(), pd.Series(y_test_b).value_counts(), pd.Series(y_val_b).value_counts())
# Out:
# Count and Number of Instances:  0    9975
# 1    9932
# Name: count, dtype: int64 1    2158
# 0    2108
# Name: count, dtype: int64 0    2136
# 1    2129
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint

def ensemble_model(x_train_b, y_train_b, x_test_b, y_test_b, original_df):
    # 1. Train the models
    ## Linear SVC Model
    svc_b = LinearSVC(class_weight='balanced')
    svc_b.fit(x_train_b, y_train_b)
    classification_report(y_test_b, svc_b.predict(x_test_b), target_names=['Not Fraud', 'Fraud'])

    ## Logistic Regression Model
    logistic_model_b = LogisticRegression()
    logistic_model_b.fit(x_train_b, y_train_b)
    logistic_model_b.score(x_train_b, y_train_b)
    classification_report(y_test_b, logistic_model_b.predict(x_test_b), target_names=['Not Fraud', 'Fraud'])

    ## Shallow Neural Network Model
    shallow_nn_b = Sequential()
    shallow_nn_b.add(InputLayer((x_train_b.shape[1],)))
    shallow_nn_b.add(Dense(2, 'relu'))
    shallow_nn_b.add(BatchNormalization())
    shallow_nn_b.add(Dense(1, 'sigmoid'))
    checkpoint = ModelCheckpoint('shallow_nn_b.keras', save_best_only=True)
    shallow_nn_b.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    shallow_nn_b.fit(x_train_b, y_train_b, validation_data=(x_test_b, y_test_b), epochs=40, callbacks=checkpoint)
    classification_report(y_test_b, (shallow_nn_b.predict(x_test_b).flatten() > 0.5).astype(int), target_names=['Not Fraud', 'Fraud'])

    ## Gradient Boosting Classifier
    gbc_b = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=2, random_state=0)
    gbc_b.fit(x_train_b, y_train_b)
    classification_report(y_test_b, gbc_b.predict(x_test_b), target_names=['Not Fraud', 'Fraud'])


    # 2. Make predictions on the validation set using each model
    y_pred_svc = svc_b.predict(x_test_b)
    y_pred_logistic = logistic_model_b.predict(x_test_b)
    y_pred_nn = (shallow_nn_b.predict(x_test_b) > 0.5).astype(int).flatten()  # Thresholding at 0.5 for binary classification
    y_pred_gbc = gbc_b.predict(x_test_b)


    # 3. Aggregate the predictions
    # Stack predictions to form a (number_of_samples, 4) array
    predictions = np.stack((y_pred_svc, y_pred_logistic, y_pred_nn, y_pred_gbc), axis=1)

    # Sum across the models to see how many labeled each instance as "Fraud"
    fraud_votes = np.sum(predictions, axis=1)

    # Label as "Fraud" (1) if 3 or more models voted "Fraud", else "Not Fraud" (0)
    final_predictions = (fraud_votes >= 3).astype(int)

    # 4. Generate the classification report
    return classification_report(y_test_b, final_predictions, target_names=['Not Fraud', 'Fraud'])

# %%
# Identify columns with non-numeric data
non_numeric_columns = df2.columns[df_ipd_ml.applymap(lambda x: isinstance(x, str)).any()]

print("Columns with non-numeric data:")
print(non_numeric_columns)
# Out:
# C:\Users\agarc\AppData\Local\Temp\ipykernel_19648\11786029.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   non_numeric_columns = df2.columns[df_ipd_ml.applymap(lambda x: isinstance(x, str)).any()]
# Columns with non-numeric data:
# Index([], dtype='object')

# %%
# Iterate over each column and identify rows with string data
for column in non_numeric_columns:
    string_data = df_ipd_ml[df_ipd_ml[column].apply(lambda x: isinstance(x, str))]
    if not string_data.empty:
        print(f"Column: {column}")
        print(string_data[[column]])  # Display the rows with string data in this column

# %% [markdown]
# ### Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression

logistic_model_b = LogisticRegression()
logistic_model_b.fit(x_train_b, y_train_b)
logistic_model_b.score(x_train_b, y_train_b)
print(classification_report(y_val_b, logistic_model_b.predict(x_val_b), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.50      0.60      0.55      2136
#        Fraud       0.50      0.40      0.45      2129
#
#     accuracy                           0.50      4265
#    macro avg       0.50      0.50      0.50      4265
# weighted avg       0.50      0.50      0.50      4265
# c:\Users\agarc\anaconda3\envs\bioenv\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### Neural Network Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
shallow_nn_b = Sequential()
shallow_nn_b.add(InputLayer((x_train_b.shape[1],)))
shallow_nn_b.add(Dense(2, 'relu'))
shallow_nn_b.add(BatchNormalization())
shallow_nn_b.add(Dense(1, 'sigmoid'))

def neural_net_predictions(x):
    return (shallow_nn_b.predict(x).flatten() > 0.5).astype(int)

checkpoint = ModelCheckpoint('shallow_nn_b.keras', save_best_only=True)
shallow_nn_b.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
shallow_nn_b.fit(x_train_b, y_train_b, validation_data=(x_val_b, y_val_b), epochs=40, callbacks=checkpoint)
print(classification_report(y_val_b, neural_net_predictions(x_val_b), target_names=['Not Fraud', 'Fraud']))
# Out:
# Epoch 1/40
# 623/623 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.4989 - loss: 0.6933 - val_accuracy: 0.4978 - val_loss: 0.6932
# Epoch 2/40
# 623/623 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5020 - loss: 0.6931 - val_accuracy: 0.5006 - val_loss: 0.6931
# Epoch 3/40
# 623/623 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4899 - loss: 0.6933 - val_accuracy: 0.5039 - val_loss: 0.6931
# Epoch 4/40
# 623/623 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4957 - loss: 0.6933 - val_accuracy: 0.5029 - val_loss: 0.6930
# Epoch 5/40
# 623/623 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5023 - loss: 0.6932 - val_accuracy: 0.5055 - val_loss: 0.6930
# Epoch 6/40
# 623/623 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5052 - loss: 0.6932 - val_accuracy: 0.5062 - val_loss: 0.6930
# Epoch 7/40
# 623/623 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4973 - loss: 0.6931 - val_accuracy: 0.5041 - val_loss: 0.6931
# Epoch 8/40
# ...

# %% [markdown]
# ### Random Forest Classifier Model

# %%
from sklearn.ensemble import RandomForestClassifier

rf_b = RandomForestClassifier(max_depth=2, n_jobs=-1)
rf_b.fit(x_train_b, y_train_b)
print(classification_report(y_val_b, rf_b.predict(x_val_b), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.50      0.69      0.58      2136
#        Fraud       0.50      0.31      0.39      2129
#
#     accuracy                           0.50      4265
#    macro avg       0.50      0.50      0.48      4265
# weighted avg       0.50      0.50      0.48      4265

# %% [markdown]
# ### Gradient Boosting Classifier Model

# %%
gbc_b = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=2, random_state=0)
gbc_b.fit(x_train_b, y_train_b)
print(classification_report(y_val_b, gbc_b.predict(x_val_b), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.51      0.54      0.53      2136
#        Fraud       0.51      0.47      0.49      2129
#
#     accuracy                           0.51      4265
#    macro avg       0.51      0.51      0.51      4265
# weighted avg       0.51      0.51      0.51      4265

# %% [markdown]
# ### Linear SVC Model

# %%
svc_b = LinearSVC(class_weight='balanced')
svc_b.fit(x_train_b, y_train_b)
print(classification_report(y_val_b, svc_b.predict(x_val_b), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.51      0.53      0.52      2136
#        Fraud       0.50      0.48      0.49      2129
#
#     accuracy                           0.51      4265
#    macro avg       0.51      0.50      0.50      4265
# weighted avg       0.51      0.51      0.50      4265

# %% [markdown]
# ### Logistic Regression CV Model

# %%
from sklearn.linear_model import LogisticRegressionCV

log = LogisticRegressionCV(cv=10,class_weight='balanced')    

# The "balanced" mode uses the values of y to automatically adjust weights inversely proportional to class frequencies
#in the input data as ``n_samples / (n_classes * np.bincount(y))``.

log.fit(x_train_b,y_train_b)
# Out:
# c:\Users\agarc\anaconda3\envs\bioenv\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\agarc\anaconda3\envs\bioenv\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
## Lets predict probability of 1 and 0 for X_train and X_val
log_train_pred_probability=log.predict_proba(x_train_b)
log_val_pred_probability=log.predict_proba(x_val_b)

# %% [markdown]
# ### Logistic Regression Model Prediction for Train and Validation

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot
fig = plt.figure(figsize=(12, 8))

# Plot train probabilities
sns.histplot(log.predict_proba(x_train_b)[:, 1], color='darkblue', kde=True, label='Train', bins=30)

# Plot validation probabilities
sns.histplot(log.predict_proba(x_val_b)[:, 1], color='firebrick', kde=True, label='Validation', bins=30)

# Add labels and title
plt.title('Distribution of Predicted Probabilities for Train and Validation Sets')
plt.xlabel('Predicted Probability')
plt.ylabel('Density')
plt.xlim([0.4, 0.6])
plt.legend()

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# ### Logistic Regression: ROC Curve

# %%
from sklearn.metrics import roc_curve, auc,precision_recall_curve
fpr, tpr, thresholds = roc_curve(y_val_b,log.predict_proba(x_val_b)[:,1])         #log_val_pred_probability[:,1])
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=1, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')

for label in range(1,10,1):
    plt.text((10-label)/10,(10-label)/10,thresholds[label*15],fontdict={'size': 14})

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
